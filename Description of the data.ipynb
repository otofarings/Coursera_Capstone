# %% [markdown]
# ### 2. Description of the data

# %% [markdown]
# For the project I am using the following data:
# 1. Open Data from the [cian](https://www.cian.ru/) website with current apartment rental offers on 03/02/2021
#     - The raw data is a .txt file with HTML code obtained from the site.
# ![file.png](attachment:file.png)
# ___

# %% [markdown]
# 2. Penza postal codes from [DELOVOIGOROD](https://postindex.delovoigorod.ru/penza/center/)
# ![file2.png](attachment:file2.png)

# %% [markdown]
# ![file1.png](attachment:file1.png)
# ___

# %% [markdown]
# 3. Location data retrieved from [Google Maps](https://www.google.com/maps)
# ![file4.png](attachment:file4.png)

# %% [markdown]
# ![file3.png](attachment:file3.png)
# ___

# %% [markdown]
# 4. The [Foursquare](https://foursquare.com/) location data
